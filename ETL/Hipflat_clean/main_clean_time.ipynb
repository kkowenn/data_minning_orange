# %%
import pandas as pd

df = pd.read_csv("time.csv")

# %%
df.head()
# Out:
#    canvas_index currencyStringFormat    date   value  \
# 0             1                USD%s  Dec 23  138562
# 1             1                USD%s  Jan 24  135913
# 2             1                USD%s  Feb 24  132184
# 3             1                USD%s  Mar 24  134525
# 4             1                USD%s  Apr 24  130812
#
#                                                 link
# 0  https://www.hipflat.co.th/en/projects/ratchada...
# 1  https://www.hipflat.co.th/en/projects/ratchada...
# 2  https://www.hipflat.co.th/en/projects/ratchada...
# 3  https://www.hipflat.co.th/en/projects/ratchada...
# 4  https://www.hipflat.co.th/en/projects/ratchada...

# %%
import re
# Define function to extract condo name using regex
def extract_condo_name(url):
    match = re.search(r'projects/([a-zA-Z0-9\-]+)', url)
    if match:
        return match.group(1)
    return None

# Apply the function to the 'link' column to create the 'condo_name' column
df['condo_name'] = df['link'].apply(extract_condo_name)

# %%
# Define function to assign 'type' based on 'currencyStringFormat'
def assign_type(row):
    if row['currencyStringFormat'] == 'USD%s':
        return 'Price'
    elif row['currencyStringFormat'] == 'USD%s/sqm':
        return 'Price Per Space'
    return 'Other'

# Apply the function to the DataFrame to create the 'type' column
df['type'] = df.apply(assign_type, axis=1)
# Show the updated DataFrame
print(df)
# Out:
#         canvas_index currencyStringFormat    date   value  \
# 0                  1                USD%s  Dec 23  138562
# 1                  1                USD%s  Jan 24  135913
# 2                  1                USD%s  Feb 24  132184
# 3                  1                USD%s  Mar 24  134525
# 4                  1                USD%s  Apr 24  130812
# ...              ...                  ...     ...     ...
# 105971             1            USD%s/sqm  Aug 24      13
# 105972             1            USD%s/sqm  Sep 24      14
# 105973             1            USD%s/sqm  Oct 24      14
# 105974             1            USD%s/sqm  Nov 24      13
# 105975             1            USD%s/sqm  Dec 24      13
#
#                                                      link  \
# 0       https://www.hipflat.co.th/en/projects/ratchada...
# 1       https://www.hipflat.co.th/en/projects/ratchada...
# 2       https://www.hipflat.co.th/en/projects/ratchada...
# 3       https://www.hipflat.co.th/en/projects/ratchada...
# 4       https://www.hipflat.co.th/en/projects/ratchada...
# ...                                                   ...
# 105971  https://www.hipflat.co.th/en/projects/sribumpe...
# 105972  https://www.hipflat.co.th/en/projects/sribumpe...
# 105973  https://www.hipflat.co.th/en/projects/sribumpe...
# 105974  https://www.hipflat.co.th/en/projects/sribumpe...
# 105975  https://www.hipflat.co.th/en/projects/sribumpe...
#
#                          condo_name             type
# 0           ratchada-city-18-juszwl            Price
# 1           ratchada-city-18-juszwl            Price
# 2           ratchada-city-18-juszwl            Price
# 3           ratchada-city-18-juszwl            Price
# 4           ratchada-city-18-juszwl            Price
# ...                             ...              ...
# 105971  sribumpen-condo-home-qrsmyt  Price Per Space
# 105972  sribumpen-condo-home-qrsmyt  Price Per Space
# 105973  sribumpen-condo-home-qrsmyt  Price Per Space
# 105974  sribumpen-condo-home-qrsmyt  Price Per Space
# 105975  sribumpen-condo-home-qrsmyt  Price Per Space
#
# [105976 rows x 7 columns]

# %%
def update_type(df):
    rent_count = 0
    rent_per_space_count = 0

    # Define the conditions to check
    conditions = ['currencyStringFormat', 'date', 'link', 'condo_name']

    for index, row in df.iterrows():
        # Select rows with the same conditions excluding the value column
        matching_rows = df[(df['currencyStringFormat'] == row['currencyStringFormat']) &
                           (df['date'] == row['date']) &
                           (df['link'] == row['link']) &
                           (df['condo_name'] == row['condo_name'])]

        for _, match in matching_rows.iterrows():
            if row['value'] < match['value']:
                if row['type'] in ['Price', 'Price Per Space']:
                    if row['type'] == 'Price':
                        df.at[index, 'type'] = 'Rent'
                        rent_count += 1
                    elif row['type'] == 'Price Per Space':
                        df.at[index, 'type'] = 'Rent Per Space'
                        rent_per_space_count += 1

    return df, rent_count, rent_per_space_count

df, rent_count, rent_per_space_count = update_type(df)
print(df)
print(f"Rent count: {rent_count}, Rent Per Space count: {rent_per_space_count}")
# Out:
#         canvas_index currencyStringFormat    date   value  \
# 0                  1                USD%s  Dec 23  138562
# 1                  1                USD%s  Jan 24  135913
# 2                  1                USD%s  Feb 24  132184
# 3                  1                USD%s  Mar 24  134525
# 4                  1                USD%s  Apr 24  130812
# ...              ...                  ...     ...     ...
# 105971             1            USD%s/sqm  Aug 24      13
# 105972             1            USD%s/sqm  Sep 24      14
# 105973             1            USD%s/sqm  Oct 24      14
# 105974             1            USD%s/sqm  Nov 24      13
# 105975             1            USD%s/sqm  Dec 24      13
#
#                                                      link  \
# 0       https://www.hipflat.co.th/en/projects/ratchada...
# 1       https://www.hipflat.co.th/en/projects/ratchada...
# 2       https://www.hipflat.co.th/en/projects/ratchada...
# 3       https://www.hipflat.co.th/en/projects/ratchada...
# 4       https://www.hipflat.co.th/en/projects/ratchada...
# ...                                                   ...
# 105971  https://www.hipflat.co.th/en/projects/sribumpe...
# 105972  https://www.hipflat.co.th/en/projects/sribumpe...
# 105973  https://www.hipflat.co.th/en/projects/sribumpe...
# 105974  https://www.hipflat.co.th/en/projects/sribumpe...
# 105975  https://www.hipflat.co.th/en/projects/sribumpe...
#
#                          condo_name             type
# 0           ratchada-city-18-juszwl            Price
# 1           ratchada-city-18-juszwl            Price
# 2           ratchada-city-18-juszwl            Price
# 3           ratchada-city-18-juszwl            Price
# 4           ratchada-city-18-juszwl            Price
# ...                             ...              ...
# 105971  sribumpen-condo-home-qrsmyt  Price Per Space
# 105972  sribumpen-condo-home-qrsmyt  Price Per Space
# 105973  sribumpen-condo-home-qrsmyt  Price Per Space
# 105974  sribumpen-condo-home-qrsmyt  Price Per Space
# 105975  sribumpen-condo-home-qrsmyt  Price Per Space
#
# [105976 rows x 7 columns]
# Rent count: 21190, Rent Per Space count: 21190

# %%
# Pivot the table: each 'date' becomes a new column with 'value' as data
pivot_df = df.pivot_table(index=['canvas_index', 'currencyStringFormat', 'link', 'condo_name'], columns='date', values='value', aggfunc='first')

# Reset index to have all columns in a flat structure
pivot_df.reset_index(inplace=True)

# %%
# Pivot the table: each 'date' becomes a new column with 'value' as data and include 'type'
pivot_df = df.pivot_table(index=['canvas_index', 'currencyStringFormat', 'link', 'condo_name', 'type'],
                          columns='date', values='value', aggfunc='first')

# Print the columns to check if "Dec 24" exists
print("Columns in pivoted DataFrame:", pivot_df.columns)

# Explicitly order the columns based on the required date sequence
ordered_columns = ["canvas_index", "currencyStringFormat", "link", "condo_name", "type",
                   "Dec 23", "Jan 24", "Feb 24", "Mar 24", "Apr 24", "May 24", "Jun 24",
                   "Jul 24", "Aug 24", "Sep 24", "Oct 24", "Nov 24","Dec 24"]

# Check if all columns exist in the DataFrame
missing_columns = [col for col in ordered_columns if col not in pivot_df.columns]
if missing_columns:
    print(f"Missing columns: {missing_columns}")
else:
    pivot_df = pivot_df[ordered_columns]

# Reset index to have all columns in a flat structure
pivot_df.reset_index(inplace=True)

# Show the updated DataFrame
print(pivot_df)
print(f"Rent count: {rent_count}, Rent Per Space count: {rent_per_space_count}")
# Out:
# Columns in pivoted DataFrame: Index(['Apr 24', 'Aug 24', 'Dec 23', 'Dec 24', 'Feb 24', 'Jan 24', 'Jul 24',
#        'Jun 24', 'Mar 24', 'May 24', 'Nov 24', 'Oct 24', 'Sep 24'],
#       dtype='object', name='date')
# Missing columns: ['canvas_index', 'currencyStringFormat', 'link', 'condo_name', 'type']
# date  canvas_index currencyStringFormat  \
# 0                1                USD%s
# 1                1                USD%s
# 2                1                USD%s
# 3                1                USD%s
# 4                1                USD%s
# ...            ...                  ...
# 8147             1            USD%s/sqm
# 8148             1            USD%s/sqm
# 8149             1            USD%s/sqm
# 8150             1            USD%s/sqm
# 8151             1            USD%s/sqm
#
# date                                               link  \
# 0     https://www.hipflat.co.th/en/projects/15-suite...
# 1     https://www.hipflat.co.th/en/projects/15-suite...
# 2     https://www.hipflat.co.th/en/projects/15-sukhu...
# 3     https://www.hipflat.co.th/en/projects/15-sukhu...
# 4     https://www.hipflat.co.th/en/projects/168-sukh...
# ...                                                 ...
# 8147  https://www.hipflat.co.th/en/projects/zenith-p...
# 8148  https://www.hipflat.co.th/en/projects/zenith-p...
# 8149  https://www.hipflat.co.th/en/projects/zenith-p...
# 8150  https://www.hipflat.co.th/en/projects/zenithar...
# 8151  https://www.hipflat.co.th/en/projects/zense-re...
#
# date                                        condo_name             type  \
# 0                                      15-suite-buacrl            Price
# 1                                      15-suite-buacrl             Rent
# 2                       15-sukhumvit-residences-htzxov            Price
# 3                       15-sukhumvit-residences-htzxov             Rent
# 4                              168-sukhumvit-36-sxiyrw            Price
# ...                                                ...              ...
# 8147                  zenith-place-sukhumvit-42-urwhyg   Rent Per Space
# 8148                  zenith-place-sukhumvit-71-rnywvv  Price Per Space
# 8149                  zenith-place-sukhumvit-71-rnywvv   Rent Per Space
# 8150               zenithar-penthouse-sukhumvit-cdmwcx  Price Per Space
# 8151  zense-residence-3ht1l37a1hu1ucu0947c3c2lct2n312n  Price Per Space
#
# date  Apr 24  Aug 24  Dec 23  Dec 24  Feb 24  Jan 24  Jul 24  Jun 24  Mar 24  \
# 0     313929  333262  308486  324894  333937  335024  318335  304842  332831
# 1       1229    1321    1288    1319    1270    1315    1246    1225    1262
# 2     313929  333262  308486  324894  333937  335024  318335  304842  332831
# 3       1229    1321    1288    1319    1270    1315    1246    1225    1262
# 4     354282  392387  352736  384009  375679  371174  375329  365107  371376
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 8147      19      20      19      20      19      19      19      19      19
# 8148    5190    5539    5287    5554    5288    5297    5263    5154    5299
# 8149      19      20      19      20      19      19      19      19      19
# 8150    4423    4620    4441    4720    4476    4473    4431    4405    4504
# 8151      11      11      11      11      11      11      11      11      11
#
# date  May 24  Nov 24  Oct 24  Sep 24
# 0     317803  328191  339569  344451
# 1       1229    1325    1358    1366
# 2     317803  328191  339569  344451
# 3       1229    1325    1358    1366
# 4     372594  389375  403184  408694
# ...      ...     ...     ...     ...
# 8147      19      20      21      21
# 8148    5215    5543    5732    5781
# 8149      19      20      21      21
# 8150    4482    4678    4765    4789
# 8151      11      11      11      11
#
# [8152 rows x 18 columns]
# Rent count: 21190, Rent Per Space count: 21190

# %%
pivot_df
# Out:
# date  canvas_index currencyStringFormat  \
# 0                1                USD%s
# 1                1                USD%s
# 2                1                USD%s
# 3                1                USD%s
# 4                1                USD%s
# ...            ...                  ...
# 8147             1            USD%s/sqm
# 8148             1            USD%s/sqm
# 8149             1            USD%s/sqm
# 8150             1            USD%s/sqm
# 8151             1            USD%s/sqm
#
# date                                               link  \
# 0     https://www.hipflat.co.th/en/projects/15-suite...
# 1     https://www.hipflat.co.th/en/projects/15-suite...
# 2     https://www.hipflat.co.th/en/projects/15-sukhu...
# 3     https://www.hipflat.co.th/en/projects/15-sukhu...
# 4     https://www.hipflat.co.th/en/projects/168-sukh...
# ...                                                 ...
# 8147  https://www.hipflat.co.th/en/projects/zenith-p...
# 8148  https://www.hipflat.co.th/en/projects/zenith-p...
# 8149  https://www.hipflat.co.th/en/projects/zenith-p...
# 8150  https://www.hipflat.co.th/en/projects/zenithar...
# 8151  https://www.hipflat.co.th/en/projects/zense-re...
#
# date                                        condo_name             type  \
# 0                                      15-suite-buacrl            Price
# 1                                      15-suite-buacrl             Rent
# 2                       15-sukhumvit-residences-htzxov            Price
# 3                       15-sukhumvit-residences-htzxov             Rent
# 4                              168-sukhumvit-36-sxiyrw            Price
# ...                                                ...              ...
# 8147                  zenith-place-sukhumvit-42-urwhyg   Rent Per Space
# 8148                  zenith-place-sukhumvit-71-rnywvv  Price Per Space
# 8149                  zenith-place-sukhumvit-71-rnywvv   Rent Per Space
# 8150               zenithar-penthouse-sukhumvit-cdmwcx  Price Per Space
# 8151  zense-residence-3ht1l37a1hu1ucu0947c3c2lct2n312n  Price Per Space
#
# date  Apr 24  Aug 24  Dec 23  Dec 24  Feb 24  Jan 24  Jul 24  Jun 24  Mar 24  \
# 0     313929  333262  308486  324894  333937  335024  318335  304842  332831
# 1       1229    1321    1288    1319    1270    1315    1246    1225    1262
# 2     313929  333262  308486  324894  333937  335024  318335  304842  332831
# 3       1229    1321    1288    1319    1270    1315    1246    1225    1262
# 4     354282  392387  352736  384009  375679  371174  375329  365107  371376
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 8147      19      20      19      20      19      19      19      19      19
# 8148    5190    5539    5287    5554    5288    5297    5263    5154    5299
# 8149      19      20      19      20      19      19      19      19      19
# 8150    4423    4620    4441    4720    4476    4473    4431    4405    4504
# 8151      11      11      11      11      11      11      11      11      11
#
# date  May 24  Nov 24  Oct 24  Sep 24
# 0     317803  328191  339569  344451
# 1       1229    1325    1358    1366
# 2     317803  328191  339569  344451
# 3       1229    1325    1358    1366
# 4     372594  389375  403184  408694
# ...      ...     ...     ...     ...
# 8147      19      20      21      21
# 8148    5215    5543    5732    5781
# 8149      19      20      21      21
# 8150    4482    4678    4765    4789
# 8151      11      11      11      11
#
# [8152 rows x 18 columns]

# %%
# Sort the DataFrame by condo_name in ascending order
pivot_df_sorted = pivot_df.sort_values(by='condo_name', ascending=True)

# %%
pivot_df_sorted
# Out:
# date  canvas_index currencyStringFormat  \
# 0                1                USD%s
# 1                1                USD%s
# 4076             1            USD%s/sqm
# 4077             1            USD%s/sqm
# 2                1                USD%s
# ...            ...                  ...
# 4072             1                USD%s
# 8150             1            USD%s/sqm
# 4074             1                USD%s
# 4075             1                USD%s
# 8151             1            USD%s/sqm
#
# date                                               link  \
# 0     https://www.hipflat.co.th/en/projects/15-suite...
# 1     https://www.hipflat.co.th/en/projects/15-suite...
# 4076  https://www.hipflat.co.th/en/projects/15-suite...
# 4077  https://www.hipflat.co.th/en/projects/15-suite...
# 2     https://www.hipflat.co.th/en/projects/15-sukhu...
# ...                                                 ...
# 4072  https://www.hipflat.co.th/en/projects/zenith-p...
# 8150  https://www.hipflat.co.th/en/projects/zenithar...
# 4074  https://www.hipflat.co.th/en/projects/zenithar...
# 4075  https://www.hipflat.co.th/en/projects/zense-re...
# 8151  https://www.hipflat.co.th/en/projects/zense-re...
#
# date                                        condo_name             type  \
# 0                                      15-suite-buacrl            Price
# 1                                      15-suite-buacrl             Rent
# 4076                                   15-suite-buacrl  Price Per Space
# 4077                                   15-suite-buacrl   Rent Per Space
# 2                       15-sukhumvit-residences-htzxov            Price
# ...                                                ...              ...
# 4072                  zenith-place-sukhumvit-71-rnywvv            Price
# 8150               zenithar-penthouse-sukhumvit-cdmwcx  Price Per Space
# 4074               zenithar-penthouse-sukhumvit-cdmwcx            Price
# 4075  zense-residence-3ht1l37a1hu1ucu0947c3c2lct2n312n            Price
# 8151  zense-residence-3ht1l37a1hu1ucu0947c3c2lct2n312n  Price Per Space
#
# date  Apr 24  Aug 24  Dec 23  Dec 24  Feb 24  Jan 24  Jul 24  Jun 24  Mar 24  \
# 0     313929  333262  308486  324894  333937  335024  318335  304842  332831
# 1       1229    1321    1288    1319    1270    1315    1246    1225    1262
# 4076    4423    4620    4441    4720    4476    4473    4431    4405    4504
# 4077      18      18      18      19      18      18      18      18      18
# 2     313929  333262  308486  324894  333937  335024  318335  304842  332831
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 4072  354282  392387  352736  384009  375679  371174  375329  365107  371376
# 8150    4423    4620    4441    4720    4476    4473    4431    4405    4504
# 4074  313929  333262  308486  324894  333937  335024  318335  304842  332831
# 4075     436     462     516     440     501     572     445     461     449
# 8151      11      11      11      11      11      11      11      11      11
#
# date  May 24  Nov 24  Oct 24  Sep 24
# 0     317803  328191  339569  344451
# 1       1229    1325    1358    1366
# 4076    4482    4678    4765    4789
# 4077      18      19      19      19
# 2     317803  328191  339569  344451
# ...      ...     ...     ...     ...
# 4072  372594  389375  403184  408694
# 8150    4482    4678    4765    4789
# 4074  317803  328191  339569  344451
# 4075     443     447     481     486
# 8151      11      11      11      11
#
# [8152 rows x 18 columns]

# %%
# Remove the 'date' and 'canvas_index' columns and group by 'condo_name'
pivot_df_grouped = pivot_df_sorted.drop(['canvas_index'], axis=1)

# Group by 'condo_name' and aggregate the values
pivot_df_grouped = pivot_df_grouped.groupby('condo_name').agg('first').reset_index()

# %%
# Check if all columns exist in the DataFrame
missing_columns = [col for col in ordered_columns if col not in pivot_df.columns]
if missing_columns:
    print(f"Missing columns: {missing_columns}")
else:
    pivot_df = pivot_df[ordered_columns]

# Sort by 'condo_name'
pivot_df = pivot_df.sort_values(by='condo_name')

# Reset index to have all columns in a flat structure
pivot_df.reset_index(inplace=True)

# Show the updated DataFrame
print(pivot_df)
print(f"Rent count: {rent_count}, Rent Per Space count: {rent_per_space_count}")
# Out:
# date  index  canvas_index currencyStringFormat  \
# 0         0             1                USD%s
# 1         1             1                USD%s
# 2      4076             1            USD%s/sqm
# 3      4077             1            USD%s/sqm
# 4         2             1                USD%s
# ...     ...           ...                  ...
# 8147   4072             1                USD%s
# 8148   8150             1            USD%s/sqm
# 8149   4074             1                USD%s
# 8150   4075             1                USD%s
# 8151   8151             1            USD%s/sqm
#
# date                                               link  \
# 0     https://www.hipflat.co.th/en/projects/15-suite...
# 1     https://www.hipflat.co.th/en/projects/15-suite...
# 2     https://www.hipflat.co.th/en/projects/15-suite...
# 3     https://www.hipflat.co.th/en/projects/15-suite...
# 4     https://www.hipflat.co.th/en/projects/15-sukhu...
# ...                                                 ...
# 8147  https://www.hipflat.co.th/en/projects/zenith-p...
# 8148  https://www.hipflat.co.th/en/projects/zenithar...
# 8149  https://www.hipflat.co.th/en/projects/zenithar...
# 8150  https://www.hipflat.co.th/en/projects/zense-re...
# 8151  https://www.hipflat.co.th/en/projects/zense-re...
#
# date                                        condo_name             type  \
# 0                                      15-suite-buacrl            Price
# 1                                      15-suite-buacrl             Rent
# 2                                      15-suite-buacrl  Price Per Space
# 3                                      15-suite-buacrl   Rent Per Space
# 4                       15-sukhumvit-residences-htzxov            Price
# ...                                                ...              ...
# 8147                  zenith-place-sukhumvit-71-rnywvv            Price
# 8148               zenithar-penthouse-sukhumvit-cdmwcx  Price Per Space
# 8149               zenithar-penthouse-sukhumvit-cdmwcx            Price
# 8150  zense-residence-3ht1l37a1hu1ucu0947c3c2lct2n312n            Price
# 8151  zense-residence-3ht1l37a1hu1ucu0947c3c2lct2n312n  Price Per Space
#
# date  Dec 23  Jan 24  Feb 24  Mar 24  Apr 24  May 24  Jun 24  Jul 24  Aug 24  \
# 0     308486  335024  333937  332831  313929  317803  304842  318335  333262
# 1       1288    1315    1270    1262    1229    1229    1225    1246    1321
# 2       4441    4473    4476    4504    4423    4482    4405    4431    4620
# 3         18      18      18      18      18      18      18      18      18
# 4     308486  335024  333937  332831  313929  317803  304842  318335  333262
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 8147  352736  371174  375679  371376  354282  372594  365107  375329  392387
# 8148    4441    4473    4476    4504    4423    4482    4405    4431    4620
# 8149  308486  335024  333937  332831  313929  317803  304842  318335  333262
# 8150     516     572     501     449     436     443     461     445     462
# 8151      11      11      11      11      11      11      11      11      11
#
# date  Sep 24  Oct 24  Nov 24  Dec 24
# 0     344451  339569  328191  324894
# 1       1366    1358    1325    1319
# 2       4789    4765    4678    4720
# 3         19      19      19      19
# 4     344451  339569  328191  324894
# ...      ...     ...     ...     ...
# 8147  408694  403184  389375  384009
# 8148    4789    4765    4678    4720
# 8149  344451  339569  328191  324894
# 8150     486     481     447     440
# 8151      11      11      11      11
#
# [8152 rows x 19 columns]
# Rent count: 21190, Rent Per Space count: 21190

# %%
# Save the grouped DataFrame to a CSV file
pivot_df.to_csv('time_test.csv', index=False)

# Provide feedback on the save operation
print("CSV file has been saved as 'time_test.csv'")
# Out:
# CSV file has been saved as 'time_test.csv'
